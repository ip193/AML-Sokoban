# %% [markdown]
# ## imports

# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path

# %%
from a_star_search import load_model

# %%
model = load_model('models/DAVI_step_10_7x7.pth', input_size=7*7*4)

# %%
import pyximport; pyximport.install()
pyximport.install(pyimport=True)
# Out:
# (<pyximport.pyximport.PyImporter at 0x7f323e579510>, None)

# %%
import gzip
import pickle

# %%
import gc
gc.collect()
# Out:
# 270

# %% [markdown]
# ## solve games

# %%
from a_star_search import search_way
from tqdm import tqdm_notebook
import time
import numpy as np
from scipy.special._ufuncs import binom

actions_len_list = []
explored_len_list = []
possible_states_list = []
solve_time = []
results = []


with gzip.open('data/sokoban-small-v0.pkl.gz', 'rb') as f:
    envs = pickle.load(f)

for env in tqdm_notebook(envs):
    start_time = time.time()
    result, explored_len = search_way(env, model)
    if type(result) is list and len(result) > 0:
        solve_time.append(time.time() - start_time)
        actions_len_list.append(len(result))
        explored_len_list.append(len(result) / float(explored_len))
        x = sum((env.room_state > 0).flatten())
        possible_states_list.append(len(result) / x * binom(x-1, env.num_boxes))
        results.append(result)
    else:
        print('ERROR, could not find a path 😢')
# Out:
# 7.4.0
# HBox(children=(IntProgress(value=0), HTML(value='')))
#   3%|▎         | 8/252 [00:00<00:10, 22.58it/s]
#   2%|▏         | 8/360 [00:00<00:03, 94.33it/s]
#  25%|██▍       | 714/2907 [00:07<00:24, 90.71it/s]
#  58%|█████▊    | 1431/2448 [00:14<00:10, 100.70it/s]
#  19%|█▉        | 212/1092 [00:02<00:08, 98.85it/s]
#   0%|          | 4/858 [00:00<00:07, 109.97it/s]
#   9%|▊         | 254/2907 [00:02<00:27, 96.67it/s]
#  14%|█▍        | 574/3990 [00:05<00:32, 103.98it/s]
#  14%|█▍        | 71/495 [00:00<00:04, 102.79it/s]
#  37%|███▋      | 499/1365 [00:04<00:08, 107.15it/s]
#  30%|██▉       | 731/2448 [00:07<00:16, 104.33it/s]
#   2%|▏         | 5/252 [00:00<00:02, 123.08it/s]
#   2%|▏         | 4/252 [00:00<00:02, 93.15it/s]
#   2%|▏         | 5/252 [00:00<00:03, 79.63it/s]
#   5%|▍         | 39/858 [00:00<00:08, 95.45it/s]
#  63%|██████▎   | 685/1092 [00:06<00:03, 104.90it/s]
#   2%|▏         | 3/168 [00:00<00:01, 130.44it/s]
#   2%|▏         | 98/4620 [00:00<00:45, 99.02it/s]
#   7%|▋         | 71/1092 [00:00<00:10, 99.85it/s]
#   1%|▏         | 23/1680 [00:00<00:16, 98.45it/s]
#   2%|▏         | 6/252 [00:00<00:02, 89.48it/s]
#  27%|██▋       | 294/1092 [00:02<00:07, 104.49it/s]
#  55%|█████▍    | 1118/2040 [00:10<00:08, 103.61it/s]
#   7%|▋         | 170/2448 [00:01<00:23, 97.90it/s]
#   3%|▎         | 127/3990 [00:01<00:40, 95.54it/s]
#   2%|▏         | 23/1365 [00:00<00:13, 97.30it/s]
#   5%|▍         | 5/105 [00:00<00:00, 118.28it/s]
#  14%|█▍        | 192/1365 [00:01<00:11, 102.93it/s]
#   4%|▍         | 16/360 [00:00<00:03, 104.21it/s]
#  22%|██▏       | 550/2448 [00:05<00:18, 105.05it/s]
#   3%|▎         | 10/360 [00:00<00:03, 97.91it/s]
#   2%|▏         | 7/360 [00:00<00:03, 95.28it/s]
#  17%|█▋        | 579/3420 [00:05<00:27, 102.86it/s]
#  20%|█▉        | 169/858 [00:01<00:06, 103.51it/s]
#   4%|▍         | 86/2040 [00:00<00:19, 100.98it/s]
#   4%|▎         | 6/168 [00:00<00:01, 112.80it/s]
#   7%|▋         | 60/858 [00:00<00:07, 100.18it/s]
#   5%|▍         | 93/2040 [00:00<00:20, 96.78it/s]
#  28%|██▊       | 816/2907 [00:07<00:19, 104.78it/s]
#   1%|          | 6/660 [00:00<00:06, 101.96it/s]
#  81%|████████  | 1982/2448 [00:18<00:04, 103.73it/s]
#  10%|▉         | 49/495 [00:00<00:04, 99.65it/s]
#  20%|██        | 344/1680 [00:03<00:13, 100.96it/s]
#   2%|▏         | 7/360 [00:00<00:03, 104.26it/s]
#  21%|██▏       | 622/2907 [00:05<00:21, 104.50it/s]
#  14%|█▎        | 548/3990 [00:05<00:32, 104.82it/s]
#   9%|▉         | 58/660 [00:00<00:05, 104.08it/s]
#   0%|          | 4/1092 [00:00<00:09, 117.20it/s]
#  11%|█         | 93/858 [00:00<00:07, 106.04it/s]
#   6%|▌         | 329/5313 [00:03<00:50, 99.61it/s]
#   4%|▎         | 87/2448 [00:00<00:23, 100.11it/s]
#  29%|██▉       | 718/2448 [00:06<00:16, 103.51it/s]
#  11%|█         | 322/2907 [00:03<00:25, 100.20it/s]
#   3%|▎         | 116/3420 [00:01<00:34, 94.74it/s]
#   8%|▊         | 374/4620 [00:04<00:47, 89.77it/s]
#   1%|          | 35/2907 [00:00<00:44, 64.05it/s]
#  34%|███▎      | 821/2448 [00:09<00:18, 89.56it/s]
#   2%|▏         | 6/252 [00:00<00:02, 111.64it/s]
#   6%|▌         | 21/360 [00:00<00:03, 105.43it/s]
#   6%|▌         | 115/2040 [00:01<00:20, 95.78it/s]
#  17%|█▋        | 486/2907 [00:05<00:25, 94.86it/s]
#  72%|███████▏  | 476/660 [00:04<00:01, 100.89it/s]
#   5%|▍         | 24/495 [00:00<00:04, 103.14it/s]
#   3%|▎         | 3/105 [00:00<00:01, 87.05it/s]
#   6%|▌         | 150/2448 [00:01<00:22, 100.06it/s]
#  26%|██▌       | 279/1092 [00:02<00:07, 106.39it/s]
#  18%|█▊        | 363/2040 [00:03<00:15, 105.62it/s]
#  51%|█████▏    | 1047/2040 [00:11<00:11, 89.26it/s]
#   1%|          | 8/1092 [00:00<00:11, 96.96it/s]
#  13%|█▎        | 218/1680 [00:02<00:15, 91.96it/s]
#  37%|███▋      | 620/1680 [00:07<00:11, 96.15it/s]
#  36%|███▌      | 239/660 [00:02<00:04, 86.76it/s]
#   1%|          | 8/660 [00:00<00:08, 79.82it/s]
#  11%|█         | 321/2907 [00:03<00:26, 98.14it/s]
#   4%|▍         | 4/105 [00:00<00:00, 121.68it/s]
#  25%|██▍       | 268/1092 [00:02<00:07, 103.16it/s]
#  33%|███▎      | 1304/3990 [00:12<00:26, 102.54it/s]
#   2%|▏         | 32/1365 [00:00<00:12, 102.82it/s]
#  76%|███████▌  | 1553/2040 [00:14<00:04, 105.27it/s]
#   0%|          | 6/2040 [00:00<00:18, 110.02it/s]
#   2%|▏         | 6/252 [00:00<00:02, 113.91it/s]
#  18%|█▊        | 434/2448 [00:04<00:19, 103.53it/s]
#  22%|██▏       | 750/3420 [00:07<00:25, 102.98it/s]
#   3%|▎         | 8/252 [00:00<00:02, 113.48it/s]
#   8%|▊         | 333/3990 [00:03<00:35, 102.86it/s]
#   3%|▎         | 28/858 [00:00<00:07, 106.21it/s]
#   1%|          | 18/2907 [00:00<00:28, 101.04it/s]
#   1%|          | 20/2448 [00:00<00:24, 98.21it/s]
#  48%|████▊     | 1388/2907 [00:13<00:14, 103.91it/s]
#   2%|▏         | 18/1092 [00:00<00:10, 98.77it/s]
#  20%|██        | 132/660 [00:01<00:05, 105.55it/s]
#   5%|▍         | 5/105 [00:00<00:00, 122.00it/s]
#   3%|▎         | 56/2040 [00:00<00:19, 104.09it/s]
#  42%|████▏     | 700/1680 [00:06<00:09, 105.91it/s]
#  20%|█▉        | 332/1680 [00:03<00:12, 105.63it/s]
#   5%|▍         | 5/105 [00:00<00:00, 121.27it/s]
#   4%|▍         | 59/1365 [00:00<00:12, 103.45it/s]
#   1%|          | 7/1365 [00:00<00:12, 112.52it/s]
#  36%|███▋      | 1057/2907 [00:10<00:17, 104.15it/s]
#  40%|████      | 676/1680 [00:06<00:09, 106.78it/s]

# %% [markdown]
# ## statistics

# %%
print('actions_len_list', np.mean(actions_len_list))
print('explored_len_list', np.mean(explored_len_list) * 100)
print('possible_states_list', np.mean(possible_states_list))
print('solve_time', np.mean(solve_time))
# Out:
# actions_len_list 11.44
# explored_len_list 31.603928024426757
# possible_states_list 75.90801913774558
# solve_time 2.9801278591156004

# %%
temp = []
explored_len_list_ = []
possible_states_list = []
for env, result, explored_len in zip(envs, results, explored_len_list):
    x = sum((env.room_state > 0).flatten())
    explored_states = 1 / explored_len * len(result)
    explored_len_list_.append(explored_states)
    possible_states = x * binom(x-1, env.num_boxes)
    possible_states_list.append(possible_states)
    temp.append(explored_states / possible_states * 100)

# %%
stats = {
    'actions_len_list': actions_len_list,
    'explored_len_list': explored_len_list_,
    'possible_states_list': possible_states_list,
    'solve_time': solve_time,
    'results': results
}

with gzip.open(f'stats/sokoban-small-v0.pkl.gz', 'wb') as f:
    pickle.dump(stats, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## plots

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(25, 25))
for idx, env in enumerate(envs):
    img = env.render(mode='rgb_array')
    fig.add_subplot(10, 10, idx + 1)
    plt.axis('off')
    plt.title(f'sokoban-small-v0 {idx + 1}')
    plt.imshow(img)
plt.axis('off')
fig.tight_layout()
plt.savefig("plots/sokoban-small-v0_unsolved.pdf")
plt.show()

# %%
from copy import deepcopy

fig = plt.figure(figsize=(25, 25))
for idx, (env, actions) in enumerate(zip(envs, results)):
    env = deepcopy(env)
    
    step = 0
    for action in actions:
        next_state, reward, done, _ = env.step(action)
        step += 1
    
    img = env.render(mode='rgb_array')
    fig.add_subplot(10, 10, idx + 1)
    plt.axis('off')
    plt.title(f'sokoban-small-v0 {idx + 1}')
    plt.imshow(img)
plt.axis('off')
fig.tight_layout()
plt.savefig("plots/sokoban-small-v0_solved.pdf")
plt.show()
